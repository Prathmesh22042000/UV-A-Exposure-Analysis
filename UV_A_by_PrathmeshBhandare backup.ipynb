    'JUNE': [8.32, 7.73, 6.04, 6.41, 6.01, 4.93, 6.42, 7.04, 4.99, 5.17, 5.33, 5.77, 6.24, 5.7, 4.85, 5.35, 4.17, 3.91, 5.22, 5.83, 5.555555556, 5.988888889, 5.53, 3.12, 3.91, 4.23, 4.73, 3.91, 3.71, 5.344444444],
    'JULY': [4.72, 4.14, 2.89, 3.1, 3.78, 2.166666667, 2.544444444, 2.99, 3, 2.466666667, 3.033333333, 2.477777778, 2.96, 3.33, 2.21, 2.44, 3.37, 2.05, 3.1, 1.25, 1.72, 1.52, 1.555555556, 3.225, 3.03, 2.288888889, 1.37, 1.75, 1.81, 2.488888889, 2.466666667],
    'AUG': [2.92, 2.54, 3.18, 2.52, 2.25, 1.76, 2.72, 3.17, 2.58, 2.56, 3.02, 2.92, 3.37, 4.19, 4.49, 4.26, 5.16, 5.01, 4.51, 4.93, 3.92, 4.32, 5.17, 6.24, 3.93, 3.35, 1.27, 2.1, 3.99, 3.97, 4.4],
    'SEP': [4.83, 3.98, 3.39, 6.04, 5.39, 6.71, 4.5, 4.5, 4.85, 3.95, 4.66, 4.5, 4.78, 4.57, 3.5, 3.73, 4.69, 3.16, 3.1, 2.96, 3.37, 6.01, 6.67, 5.82, 6.15, 7.06, 6.41, 6.88, 5.89],
    'OCT': [4.58, 5.97, 5.36, 3.68, 5.68, 7.64, 5.91, 6.78, 6.59, 6.17, 5.79, 6.79, 6.53, 6.71, 6.82, 6.76, 6.96, 5.85, 7.75, 7.05, 5.99, 6.51, 7.33, 6.2, 6.57, 5.65, 7.14, 8.26, 8.2, 8.84, 7.51],
    'NOV': [6.775, 8.3, 8.7, 8.05, 8.225, 8.2875, 8.6, 9.0625, 8.8125, 8.9, 9.15, 9.0375, 9.0625, 8.9375, 8.1625, 8.825, 8.875, 8.2875, 8.45, 7.7125, 8.1625, 8.2125, 8.0625, 7.5625, 6.8125, 7.3, 7.6125, 5.975, 8.4625, 7.65],
    'DEC': [6.62, 7.63, 7.9, 6.98, 6.93, 8.19, 8.47, 8.48, 8.67, 8.65, 7.81, 8.12, 7.61, 6.64, 7.31, 8.2, 7.68, 8.13, 7.92, 8.31, 8.33, 7.388888889, 8.16, 7.93, 8.08, 8.4, 8.36, 8.36, 8.24, 8.31, 7.39]
}

def generate_data_for_365_days(data_dict):
    return {key: np.tile(data_dict[key], 365 // len(data_dict[key]) + 1)[:365] for key in data_dict}

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Generate an array of days (1 to 365)
days = np.arange(1, 366)

# Equalize the lengths of data arrays to cover 365 days
uva_data = generate_data_for_365_days(uva_data)
bhss_data = generate_data_for_365_days(bhss_data)

# Plot UV A data on the primary y-axis
ax.plot(days, uva_data['JAN'], label='UV A', color='#FF5757', linewidth=2)

# Create a secondary y-axis for BHSS data
ax2 = ax.twinx()
ax2.plot(days, bhss_data['JAN'], label='BHSS', color='#5799FF', linewidth=2)

# Set y-axis labels for both datasets
ax.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)
ax2.set_ylabel('BHSS (W/m^2) ', color='#5799FF', fontsize=14)

# Set x-axis label
ax.set_xlabel('Days', fontsize=14)

# Add grid lines for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=6,
          borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('UV A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'uv_bhss_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Display the plot
plt.show()

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")
# Out:
# Plot saved as: uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data
uva_data = [
    # January
    7.388602, 7.388602, 7.732231, 7.385131, 6.694402, 7.535541, 7.735702, 7.269431, 7.6362, 7.669753,
    7.669753, 7.887269, 6.991751, 7.272902, 7.193069, 7.442981, 7.829419, 8.148751, 8.314202, 8.002969,
    8.176519, 7.93702, 8.234369, 7.54364, 8.23784, 7.771569, 7.945119, 8.310731, 8.429902, 8.30726, 7.041502,
    # February
    7.768098, 8.350069, 8.16842, 8.38825, 8.164949, 8.842951, 8.697169, 8.581469, 8.859149, 8.576841,
    9.190051, 8.889231, 8.974849, 8.9089, 9.387898, 9.471202, 9.805575, 9.756981, 9.31385, 9.289553,
    9.537151, 9.7188, 9.074351, 9.814831, 10.23945, 10.330853, 10.00805, 9.256, 8.755019,
    # March
    9.622769, 9.553349, 10.5287, 10.0659, 9.89235, 10.413, 10.842247, 10.895469, 11.126869, 10.743902,
    11.123398, 11.091002, 11.057449, 11.13034, 9.89235, 9.641281, 10.70225, 10.1816, 11.4543, 11.955281,
    12.10222, 12.226019, 11.47744, 11.041251, 10.281102, 10.660598, 10.231351, 10.335481, 11.025053, 11.3386,
    11.404549,
    # April
    11.619751, 11.85925, 11.531819, 10.9915, 11.029681, 11.126869, 11.781731, 11.839581, 11.4543, 11.029681,
    10.721919, 11.184719, 11.883547, 11.785202, 11.8014, 11.156951, 11.420747, 12.280398, 12.573119, 12.1485,
    12.707331, 13.459381, 13.233766, 13.681525, 13.520702, 13.290459, 12.727, 12.191309, 12.350975, 12.828816,
    # May
    13.636402, 13.271947, 13.255749, 13.507975, 13.5369, 13.3055, 13.638716, 13.271947, 13.406159, 13.0741,
    13.204841, 13.487149, 11.62785, 12.929475, 12.78485, 11.011169, 13.103025, 12.9584, 13.71045, 14.1154,
    13.818051, 13.408473, 14.028625, 12.880881, 13.797225, 13.850447, 12.871625, 12.727, 13.1898, 12.585846,
    13.343681,
    # June
    13.057902, 11.930984, 12.457419, 11.092159, 11.388351, 9.965241, 11.288849, 11.698427, 10.115651, 10.341266,
    9.7188, 10.659441, 12.161227, 11.968008, 10.35515, 10.6444, 10.6444, 10.20474, 11.929827, 11.6857, 11.041251,
    11.904373, 12.09065, 9.81136, 9.93863, 9.268727, 10.789025, 8.611551, 9.966398, 10.2973,
    # July
    8.8, 9.6, 9.69, 9.5, 9.54, 9.32, 9.14, 8.65, 8.53, 8.5, 8.74, 8.64, 9.09, 9.45,
    # April
    9.24, 9.39, 9.47, 9.31, 9.31, 8.35, 9.3, 9.15, 9.12, 8.67, 8.78, 9.26, 9.49, 9, 9.37, 9.04, 9.34, 9.89, 9.36,
    9.19, 9.86, 10.4, 10.14, 10.39, 10.19, 10.44, 9.92, 9.46, 10.05, 9.844444444,
    # May
    10.14, 10.14, 10.5, 10.47, 10.22, 10.48, 9.51, 9.29, 9.57, 10.12, 10.1, 10.34, 9.622222222, 8.52, 8.49, 7.87,
    9.93, 8.61, 9.78, 9.85, 10.14, 10.08, 10.58, 10.17, 10.64, 10.03, 9.58, 10.08, 9.6, 8.95, 10.1,
    # June
    8.32, 7.73, 6.04, 6.41, 6.01, 4.93, 6.42, 7.04, 4.99, 5.17, 5.33, 5.77, 6.24, 5.7, 4.85, 5.35, 4.17, 3.91,
    5.22, 5.83, 5.555555556, 5.988888889, 5.53, 3.12, 3.91, 4.23, 4.73, 3.91, 3.71, 5.344444444,
    # July
    4.72, 4.14, 2.89, 3.1, 3.78, 2.166666667, 2.544444444, 2.99, 3, 2.466666667, 3.033333333, 2.477777778, 2.96,
    3.33, 2.21, 2.44, 3.37, 2.05, 3.1, 1.25, 1.72, 1.52, 1.555555556, 3.225, 3.03, 2.288888889, 1.37, 1.75, 1.81,
    2.488888889, 2.466666667,
    # August
    2.92, 2.54, 3.18, 2.52, 2.25, 1.76, 2.72, 3.17, 2.58, 2.56, 3.02, 2.92, 3.37, 4.19, 4.49, 4.26, 5.16, 5.01,
    4.51, 4.93, 3.92, 4.32, 5.17, 6.24, 3.93, 3.35, 1.27, 2.1, 3.99, 3.97,
    # September
    4.83, 3.98, 3.39, 6.04, 5.39, 6.71, 4.5, 4.5, 4.85, 3.95, 4.66, 4.5, 4.78, 4.57, 3.5, 3.73, 4.69, 3.16, 3.1,
    2.96, 3.37, 6.01, 6.67, 5.82, 6.15, 7.06, 6.41, 6.88,
    # October
    4.58, 5.97, 5.36, 3.68, 5.68, 7.64, 5.91, 6.78, 6.59, 6.17, 5.79, 6.79, 6.53, 6.71, 6.82, 6.76, 6.96, 5.85,
    7.75, 7.05, 5.99, 6.51, 7.33, 6.2, 6.57, 5.65, 7.14, 8.26, 8.2, 8.84, 7.51,
    # November
    6.775, 8.3, 8.7, 8.05, 8.225, 8.2875, 8.6, 9.0625, 8.8125, 8.9, 9.15, 9.0375, 9.0625, 8.9375, 8.1625, 8.825,
    8.875, 8.2875, 8.45, 7.7125, 8.1625, 8.2125, 8.0625, 7.5625, 6.8125, 7.3, 7.6125, 5.975, 8.4625, 7.65,
    # December
    6.62, 7.63, 7.9, 6.98, 6.93, 8.19, 8.47, 8.48, 8.67, 8.65, 7.81, 8.12, 7.61, 6.64, 7.31, 8.2, 7.68, 8.13,
    7.92, 8.31, 8.33, 7.388888889, 8.16, 7.93, 8.08, 8.4, 8.36, 8.36, 8.24, 8.31, 7.39
]

def generate_data_for_365_days(data_list):
    data_array = np.array(data_list)
    return np.tile(data_array, 365 // len(data_array) + 1)[:365].tolist()

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Generate an array of days (1 to 365)
days = np.arange(1, 366)

# Equalize the lengths of data arrays to cover 365 days
uva_data = {key: generate_data_for_365_days(uva_data) for key in range(12)}
bhss_data = {key: generate_data_for_365_days(bhss_data) for key in range(12)}

# Plot UV A data on the primary y-axis
ax.plot(days, uva_data[0], label='UV A', color='#FF5757', linewidth=2)

# Create a secondary y-axis for BHSS data
ax2 = ax.twinx()
ax2.plot(days, bhss_data[0], label='BHSS', color='#5799FF', linewidth=2)

# Set y-axis labels for both datasets
ax.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)
ax2.set_ylabel('BHSS (W/m^2) ', color='#5799FF', fontsize=14)

# Set x-axis label
ax.set_xlabel('Days', fontsize=14)

# Add grid lines for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=6,
          borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('UV A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'uv_bhss_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Display the plot
plt.show()

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")
# Out:
# Plot saved as: uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data
uva_data = [
    # January
    7.388602, 7.388602, 7.732231, 7.385131, 6.694402, 7.535541, 7.735702, 7.269431, 7.6362, 7.669753,
    7.669753, 7.887269, 6.991751, 7.272902, 7.193069, 7.442981, 7.829419, 8.148751, 8.314202, 8.002969,
    8.176519, 7.93702, 8.234369, 7.54364, 8.23784, 7.771569, 7.945119, 8.310731, 8.429902, 8.30726, 7.041502,
    # February
    7.768098, 8.350069, 8.16842, 8.38825, 8.164949, 8.842951, 8.697169, 8.581469, 8.859149, 8.576841,
    9.190051, 8.889231, 8.974849, 8.9089, 9.387898, 9.471202, 9.805575, 9.756981, 9.31385, 9.289553,
    9.537151, 9.7188, 9.074351, 9.814831, 10.23945, 10.330853, 10.00805, 9.256, 8.755019,
]

# BHSS data
bhss_data = [
    # January
    7.49, 7.811111111, 8.19, 8.1, 7.73, 8.43, 8.72, 8.79, 8.29, 8.36, 9, 8.9, 8.19, 8.19, 7.96, 8.31, 8.89, 8.6,
    9.15, 8.22, 8.08, 8.7, 8.2, 8.15, 8.72, 8.33, 8.46, 9.13, 9.23, 9.24, 8.86,
    # February
    8.51, 8.74, 8.68, 8.96, 8.22, 8.65, 8.45, 8.77, 9.13, 8.38, 9.01, 8.34, 8.78, 8.88, 9.14, 9.46, 9.74, 9.9,
    9.48, 9.53, 9, 9.64, 9.33, 9.39, 9.87, 9.53, 9.74, 8.8, 8.133333333,
]

# Generate an array of days (1 to 60)
days = np.arange(1, 61)

# Plot UV A data on the primary y-axis
plt.plot(days, uva_data[:60], label='UV A', color='#FF5757', linewidth=2)

# Create a secondary y-axis for BHSS data
plt.twinx()
plt.plot(days, bhss_data[:60], label='BHSS', color='#5799FF', linewidth=2)

# Set y-axis labels for both datasets
plt.ylabel('UV A (W/m^2) / BHSS (W/m^2)', fontsize=14)

# Set x-axis label
plt.xlabel('Days', fontsize=14)

# Add grid lines for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
plt.legend(loc='upper left', fontsize=6, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('WINTER UV A and BHSS Data Over Days', fontsize=12)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data
uva_data = [
    # January
    7.388602, 7.388602, 7.732231, 7.385131, 6.694402, 7.535541, 7.735702, 7.269431, 7.6362, 7.669753,
    7.669753, 7.887269, 6.991751, 7.272902, 7.193069, 7.442981, 7.829419, 8.148751, 8.314202, 8.002969,
    8.176519, 7.93702, 8.234369, 7.54364, 8.23784, 7.771569, 7.945119, 8.310731, 8.429902, 8.30726, 7.041502,
    # February
    7.768098, 8.350069, 8.16842, 8.38825, 8.164949, 8.842951, 8.697169, 8.581469, 8.859149, 8.576841,
    9.190051, 8.889231, 8.974849, 8.9089, 9.387898, 9.471202, 9.805575, 9.756981, 9.31385, 9.289553,
    9.537151, 9.7188, 9.074351, 9.814831, 10.23945, 10.330853, 10.00805, 9.256, 8.755019,
]

# BHSS data
bhss_data = [
   # January
    7.49, 7.811111111, 8.19, 8.1, 7.73, 8.43, 8.72, 8.79, 8.29, 8.36, 9, 8.9, 8.19, 8.19, 7.96, 8.31, 8.89, 8.6,
    9.15, 8.22, 8.08, 8.7, 8.2, 8.15, 8.72, 8.33, 8.46, 9.13, 9.23, 9.24, 8.86,
    # February
    8.51, 8.74, 8.68, 8.96, 8.22, 8.65, 8.45, 8.77, 9.13, 8.38, 9.01, 8.34, 8.78, 8.88, 9.14, 9.46, 9.74, 9.9,
    9.48, 9.53, 9, 9.64, 9.33, 9.39, 9.87, 9.53, 9.74, 8.8, 8.133333333,
]

# Generate an array of days (1 to 60)
days = np.arange(1, 61)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days, uva_data[:60], label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Days', fontsize=14)
ax1.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days, bhss_data[:60], label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=6, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('WINTER UV A and BHSS Data Over Days', fontsize=12)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data
uva_data = [
     # January
    7.388602, 7.388602, 7.732231, 7.385131, 6.694402, 7.535541, 7.735702, 7.269431, 7.6362, 7.669753,
    7.669753, 7.887269, 6.991751, 7.272902, 7.193069, 7.442981, 7.829419, 8.148751, 8.314202, 8.002969,
    8.176519, 7.93702, 8.234369, 7.54364, 8.23784, 7.771569, 7.945119, 8.310731, 8.429902, 8.30726, 7.041502,
    # February
    7.768098, 8.350069, 8.16842, 8.38825, 8.164949, 8.842951, 8.697169, 8.581469, 8.859149, 8.576841,
    9.190051, 8.889231, 8.974849, 8.9089, 9.387898, 9.471202, 9.805575, 9.756981, 9.31385, 9.289553,
    9.537151, 9.7188, 9.074351, 9.814831, 10.23945, 10.330853, 10.00805, 9.256, 8.755019,
]

# BHSS data
bhss_data = [
 # January
    7.49, 7.811111111, 8.19, 8.1, 7.73, 8.43, 8.72, 8.79, 8.29, 8.36, 9, 8.9, 8.19, 8.19, 7.96, 8.31, 8.89, 8.6,
    9.15, 8.22, 8.08, 8.7, 8.2, 8.15, 8.72, 8.33, 8.46, 9.13, 9.23, 9.24, 8.86,
    # February
    8.51, 8.74, 8.68, 8.96, 8.22, 8.65, 8.45, 8.77, 9.13, 8.38, 9.01, 8.34, 8.78, 8.88, 9.14, 9.46, 9.74, 9.9,
    9.48, 9.53, 9, 9.64, 9.33, 9.39, 9.87, 9.53, 9.74, 8.8, 8.133333333,
]
# Generate an array of days (1 to 60)
days = np.arange(1, 61)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days, uva_data[:60], label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Days', fontsize=14)
ax1.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days, bhss_data[:60], label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=6, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('WINTER UV A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'uv_bhss_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")

# Display the plot
plt.show()
# Out:
# Plot saved as: uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data
uva_data_march_may = [
    # March
    9.622769, 9.553349, 10.5287, 10.0659, 9.89235, 10.413, 10.842247, 10.895469, 11.126869, 10.743902, 11.123398, 11.091002,
    11.057449, 11.13034, 9.89235, 9.641281, 10.70225, 10.1816, 11.4543, 11.955281, 12.10222, 12.226019, 11.47744, 11.041251,
    10.281102, 10.660598, 10.231351, 10.335481, 11.025053, 11.3386, 11.404549,
    # April
    11.619751, 11.85925, 11.531819, 10.9915, 11.029681, 11.126869, 11.781731, 11.839581, 11.4543, 11.029681, 10.721919,
    11.184719, 11.883547, 11.785202, 11.8014, 11.156951, 11.420747, 12.280398, 12.573119, 12.1485, 12.707331, 13.459381,
    13.233766, 13.681525, 13.520702, 13.290459, 12.727, 12.191309, 12.350975, 12.828816,
    # May
    13.636402, 13.271947, 13.255749, 13.507975, 13.5369, 13.3055, 13.638716, 13.271947, 13.406159, 13.0741, 13.204841,
    13.487149, 11.62785, 12.929475, 12.78485, 11.011169, 13.103025, 12.9584, 13.71045, 14.1154, 13.818051, 13.408473,
    14.028625, 12.880881, 13.797225, 13.850447, 12.871625, 12.727, 13.1898, 12.585846, 13.343681,
]

# BHSS data
bhss_data_march_may = [
    # March
    7.7, 9.07, 9.29, 8.83, 8, 9.13, 9.31, 9.36, 8.79, 8.88, 9.211111111, 8.94, 8.74, 8.88, 8.122222222, 8.12, 9, 8.8, 9.6,
    9.69, 9.5, 9.54, 9.32, 9.14, 8.65, 8.53, 8.5, 8.74, 8.64, 9.09, 9.45,
    # April
    9.24, 9.39, 9.47, 9.31, 9.31, 8.35, 9.3, 9.15, 9.12, 8.67, 8.78, 9.26, 9.49, 9, 9.37, 9.04, 9.34, 9.89, 9.36, 9.19, 9.86,
    10.4, 10.14, 10.39, 10.19, 10.44, 9.92, 9.46, 10.05, 9.844444444,
    # May
    10.14, 10.14, 10.5, 10.47, 10.22, 10.48, 9.51, 9.29, 9.57, 10.12, 10.1, 10.34, 9.622222222, 8.52, 8.49, 7.87, 9.93, 8.61,
    9.78, 9.85, 10.14, 10.08, 10.58, 10.17, 10.64, 10.03, 9.58, 10.08, 9.6, 8.95, 10.1,
]

# Generate an array of days (1 to 90 for March to May)
days = np.arange(1, 93)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days, uva_data_march_may, label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Days', fontsize=14)
ax1.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days, bhss_data_march_may, label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=8, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('Pre-Monsoon UV A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'uv_bhss_pre_monsoon_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")

# Display the plot
plt.show()
# Out:
# Plot saved as: uv_bhss_pre_monsoon_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data
uva_data_march_may = [
    # March
    9.622769, 9.553349, 10.5287, 10.0659, 9.89235, 10.413, 10.842247, 10.895469, 11.126869, 10.743902, 11.123398, 11.091002,
    11.057449, 11.13034, 9.89235, 9.641281, 10.70225, 10.1816, 11.4543, 11.955281, 12.10222, 12.226019, 11.47744, 11.041251,
    10.281102, 10.660598, 10.231351, 10.335481, 11.025053, 11.3386, 11.404549,
    # April
    11.619751, 11.85925, 11.531819, 10.9915, 11.029681, 11.126869, 11.781731, 11.839581, 11.4543, 11.029681, 10.721919,
    11.184719, 11.883547, 11.785202, 11.8014, 11.156951, 11.420747, 12.280398, 12.573119, 12.1485, 12.707331, 13.459381,
    13.233766, 13.681525, 13.520702, 13.290459, 12.727, 12.191309, 12.350975, 12.828816,
    # May
    13.636402, 13.271947, 13.255749, 13.507975, 13.5369, 13.3055, 13.638716, 13.271947, 13.406159, 13.0741, 13.204841,
    13.487149, 11.62785, 12.929475, 12.78485, 11.011169, 13.103025, 12.9584, 13.71045, 14.1154, 13.818051, 13.408473,
    14.028625, 12.880881, 13.797225, 13.850447, 12.871625, 12.727, 13.1898, 12.585846, 13.343681,
]

# BHSS data
bhss_data_march_may = [
    # March
    7.7, 9.07, 9.29, 8.83, 8, 9.13, 9.31, 9.36, 8.79, 8.88, 9.211111111, 8.94, 8.74, 8.88, 8.122222222, 8.12, 9, 8.8, 9.6,
    9.69, 9.5, 9.54, 9.32, 9.14, 8.65, 8.53, 8.5, 8.74, 8.64, 9.09, 9.45,
    # April
    9.24, 9.39, 9.47, 9.31, 9.31, 8.35, 9.3, 9.15, 9.12, 8.67, 8.78, 9.26, 9.49, 9, 9.37, 9.04, 9.34, 9.89, 9.36, 9.19, 9.86,
    10.4, 10.14, 10.39, 10.19, 10.44, 9.92, 9.46, 10.05, 9.844444444,
    # May
    10.14, 10.14, 10.5, 10.47, 10.22, 10.48, 9.51, 9.29, 9.57, 10.12, 10.1, 10.34, 9.622222222, 8.52, 8.49, 7.87, 9.93, 8.61,
    9.78, 9.85, 10.14, 10.08, 10.58, 10.17, 10.64, 10.03, 9.58, 10.08, 9.6, 8.95, 10.1,
]

# Generate an array of days (1 to 90)
days_march_may = np.arange(1, 93)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days_march_may, uva_data_march_may, label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Days', fontsize=14)
ax1.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days_march_may, bhss_data_march_may, label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=6, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('Pre Monsoon UV A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'pre_monsoon_uv_bhss_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")

# Display the plot
plt.show()
# Out:
# Plot saved as: pre_monsoon_uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_uv_bhss_data(days, uva_data, bhss_data, title):
    fig, ax1 = plt.subplots(figsize=(10, 6))

    # Plot UV A data on the primary y-axis
    ax1.plot(days, uva_data, label='UV A', color='#FF5757', linewidth=2)
    ax1.set_xlabel('Days', fontsize=14)
    ax1.set_ylabel('UV A (W/m^2)', color='#FF5757', fontsize=14)

    # Create a secondary y-axis for BHSS data
    ax2 = ax1.twinx()
    ax2.plot(days, bhss_data, label='BHSS', color='#5799FF', linewidth=2)
    ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

    # Add grid lines for better readability
    ax1.grid(True, linestyle='--', alpha=0.7)

    # Customize legend with a border box and adjust fontsize
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=6, borderpad=1, fancybox=True, edgecolor='black')

    # Add title
    plt.title(title, fontsize=12)

    # Save the plot as a PNG image file
    output_file_path = f'{title.lower().replace(" ", "_")}_plot.png'
    plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

    # Print the path to the saved image file
    print(f"Plot saved as: {output_file_path}")

    # Display the plot
    plt.show()

# UV A data for pre-monsoon months
uva_data_march_may = [
    # March
    9.622769, 9.553349, 10.5287, 10.0659, 9.89235, 10.413, 10.842247, 10.895469, 11.126869, 10.743902, 11.123398, 11.091002,
    11.057449, 11.13034, 9.89235, 9.641281, 10.70225, 10.1816, 11.4543, 11.955281, 12.10222, 12.226019, 11.47744, 11.041251,
    10.281102, 10.660598, 10.231351, 10.335481, 11.025053, 11.3386, 11.404549,
    # April
    11.619751, 11.85925, 11.531819, 10.9915, 11.029681, 11.126869, 11.781731, 11.839581, 11.4543, 11.029681, 10.721919,
    11.184719, 11.883547, 11.785202, 11.8014, 11.156951, 11.420747, 12.280398, 12.573119, 12.1485, 12.707331, 13.459381,
    13.233766, 13.681525, 13.520702, 13.290459, 12.727, 12.191309, 12.350975, 12.828816,
    # May
    13.636402, 13.271947, 13.255749, 13.507975, 13.5369, 13.3055, 13.638716, 13.271947, 13.406159, 13.0741, 13.204841,
    13.487149, 11.62785, 12.929475, 12.78485, 11.011169, 13.103025, 12.9584, 13.71045, 14.1154, 13.818051, 13.408473,
    14.028625, 12.880881, 13.797225, 13.850447, 12.871625, 12.727, 13.1898, 12.585846, 13.343681,
]

# BHSS data
bhss_data_march_may = [
    # March
    7.7, 9.07, 9.29, 8.83, 8, 9.13, 9.31, 9.36, 8.79, 8.88, 9.211111111, 8.94, 8.74, 8.88, 8.122222222, 8.12, 9, 8.8, 9.6,
    9.69, 9.5, 9.54, 9.32, 9.14, 8.65, 8.53, 8.5, 8.74, 8.64, 9.09, 9.45,
    # April
    9.24, 9.39, 9.47, 9.31, 9.31, 8.35, 9.3, 9.15, 9.12, 8.67, 8.78, 9.26, 9.49, 9, 9.37, 9.04, 9.34, 9.89, 9.36, 9.19, 9.86,
    10.4, 10.14, 10.39, 10.19, 10.44, 9.92, 9.46, 10.05, 9.844444444,
    # May
    10.14, 10.14, 10.5, 10.47, 10.22, 10.48, 9.51, 9.29, 9.57, 10.12, 10.1, 10.34, 9.622222222, 8.52, 8.49, 7.87, 9.93, 8.61,
    9.78, 9.85, 10.14, 10.08, 10.58, 10.17, 10.64, 10.03, 9.58, 10.08, 9.6, 8.95, 10.1,
]

# Generate an array of days (1 to 90)
days_march_may = np.arange(1, 93)

# Plot UV A and BHSS data for pre-monsoon months
plot_uv_bhss_data(days_march_may, uva_data_march_may, bhss_data_march_may, 'Pre Monsoon UV A and BHSS Data')
# Out:
# Plot saved as: pre_monsoon_uv_a_and_bhss_data_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data for monsoon months
uva_data_monsoon = [
    # June
    13.057902, 11.930984, 12.457419, 11.092159, 11.388351, 9.965241, 11.288849, 11.698427, 10.115651, 10.341266, 9.7188,
    10.659441, 12.161227, 11.968008, 10.35515, 10.6444, 10.6444, 10.20474, 11.929827, 11.6857, 11.041251, 11.904373,
    12.09065, 9.81136, 9.93863, 9.268727, 10.789025, 8.611551, 9.966398, 10.2973,
    # July
    10.544898, 9.89235, 8.715681, 9.863425, 10.099453, 8.395192, 9.7188, 9.338147, 9.969869, 8.991047, 9.08245, 8.844108,
    9.053525, 10.023091, 8.777002, 8.458827, 9.037327, 8.26098, 8.523619, 8.461141, 8.78163, 7.842146, 7.998341, 8.870719,
    9.77665, 7.6362, 7.970573, 8.04115, 8.252881, 8.5618, 7.202325,
    # August
    8.626592, 9.667892, 9.6031, 8.085116, 8.149908, 8.5618, 8.575684, 8.61965, 8.73535, 9.0246, 9.616984, 9.183109,
    9.165754, 9.64938, 10.11218, 9.1403, 10.040446, 10.28573, 10.215153, 10.425727, 9.516325, 9.937473, 10.557625, 10.167716,
    9.500127, 8.008754, 8.033051, 8.38825, 8.5618, 9.734998, 9.675991,
    # September
    9.884251, 9.6031, 8.690227, 9.900449, 9.333519, 10.81795, 9.590373, 10.514816, 10.44771, 9.461946, 9.384427, 9.84607,
    10.104081, 11.2229, 8.343127, 7.718347, 9.184266, 9.78822, 7.91388, 8.374366, 9.900449, 11.671816, 10.35515, 11.51215,
    11.121084, 11.28075, 10.47085, 10.197798, 9.156498, 10.201269,
]

# BHSS data for monsoon months
bhss_data_monsoon = [
    # June
    8.32, 7.73, 6.04, 6.41, 6.01, 4.93, 6.42, 7.04, 4.99, 5.17, 5.33, 5.77, 6.24, 5.7, 4.85, 5.35, 4.17, 3.91, 5.22,
    5.83, 5.555555556, 5.988888889, 5.53, 3.12, 3.91, 4.23, 4.73, 3.91, 3.71, 5.344444444,
    # July
    4.72, 4.14, 2.89, 3.1, 3.78, 2.166666667, 2.544444444, 2.99, 3, 2.466666667, 3.033333333, 2.477777778, 2.96, 3.33,
    2.21, 2.44, 3.37, 2.05, 3.1, 1.25, 1.72, 1.52, 1.555555556, 3.225, 3.03, 2.288888889, 1.37, 1.75, 1.81, 2.488888889,
    2.466666667,
    # August
    2.92, 2.54, 3.18, 2.52, 2.25, 1.76, 2.72, 3.17, 2.58, 2.56, 3.02, 2.92, 3.37, 4.19, 4.49, 4.26, 5.16, 5.01, 4.51, 4.93,
    3.92, 4.32, 5.17, 6.24, 3.93, 3.35, 1.27, 2.1, 3.99, 3.97, 4.4,
    # September
    4.83, 3.98, 3.39, 6.04, 5.39, 6.71, 4.5, 4.5, 4.85, 3.95, 4.66, 4.5, 4.78, 4.57, 3.5, 3.73, 4.69, 3.16, 3.1, 2.96,
    3.37, 6.01, 6.67, 5.82, 6.15, 7.06, 6.41, 6.88, 5.89, 7.09,
]

# Generate an array of days for monsoon months
days_monsoon = np.arange(1, len(uva_data_monsoon) + 1)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days_monsoon, uva_data_monsoon, label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Julian Days', fontsize=14)
ax1.set_ylabel('UV-A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days_monsoon, bhss_data_monsoon, label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=8, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('Monsoon UV-A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'monsoon_uv_bhss_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")

# Display the plot
plt.show()
# Out:
# Plot saved as: monsoon_uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data for monsoon months
uva_data_monsoon = [
    # June
    13.057902, 11.930984, 12.457419, 11.092159, 11.388351, 9.965241, 11.288849, 11.698427, 10.115651, 10.341266, 9.7188,
    10.659441, 12.161227, 11.968008, 10.35515, 10.6444, 10.6444, 10.20474, 11.929827, 11.6857, 11.041251, 11.904373,
    12.09065, 9.81136, 9.93863, 9.268727, 10.789025, 8.611551, 9.966398, 10.2973,
    # July
    10.544898, 9.89235, 8.715681, 9.863425, 10.099453, 8.395192, 9.7188, 9.338147, 9.969869, 8.991047, 9.08245, 8.844108,
    9.053525, 10.023091, 8.777002, 8.458827, 9.037327, 8.26098, 8.523619, 8.461141, 8.78163, 7.842146, 7.998341, 8.870719,
    9.77665, 7.6362, 7.970573, 8.04115, 8.252881, 8.5618, 7.202325,
    # August
    8.626592, 9.667892, 9.6031, 8.085116, 8.149908, 8.5618, 8.575684, 8.61965, 8.73535, 9.0246, 9.616984, 9.183109,
    9.165754, 9.64938, 10.11218, 9.1403, 10.040446, 10.28573, 10.215153, 10.425727, 9.516325, 9.937473, 10.557625, 10.167716,
    9.500127, 8.008754, 8.033051, 8.38825, 8.5618, 9.734998, 9.675991,
    # September
    9.884251, 9.6031, 8.690227, 9.900449, 9.333519, 10.81795, 9.590373, 10.514816, 10.44771, 9.461946, 9.384427, 9.84607,
    10.104081, 11.2229, 8.343127, 7.718347, 9.184266, 9.78822, 7.91388, 8.374366, 9.900449, 11.671816, 10.35515, 11.51215,
    11.121084, 11.28075, 10.47085, 10.197798, 9.156498, 10.201269,
]

# BHSS data for monsoon months
bhss_data_monsoon = [
    # June
    8.32, 7.73, 6.04, 6.41, 6.01, 4.93, 6.42, 7.04, 4.99, 5.17, 5.33, 5.77, 6.24, 5.7, 4.85, 5.35, 4.17, 3.91, 5.22,
    5.83, 5.555555556, 5.988888889, 5.53, 3.12, 3.91, 4.23, 4.73, 3.91, 3.71, 5.344444444,
    # July
    4.72, 4.14, 2.89, 3.1, 3.78, 2.166666667, 2.544444444, 2.99, 3, 2.466666667, 3.033333333, 2.477777778, 2.96, 3.33,
    2.21, 2.44, 3.37, 2.05, 3.1, 1.25, 1.72, 1.52, 1.555555556, 3.225, 3.03, 2.288888889, 1.37, 1.75, 1.81, 2.488888889,
    2.466666667,
    # August
    2.92, 2.54, 3.18, 2.52, 2.25, 1.76, 2.72, 3.17, 2.58, 2.56, 3.02, 2.92, 3.37, 4.19, 4.49, 4.26, 5.16, 5.01, 4.51, 4.93,
    3.92, 4.32, 5.17, 6.24, 3.93, 3.35, 1.27, 2.1, 3.99, 3.97, 4.4,
    # September
    4.83, 3.98, 3.39, 6.04, 5.39, 6.71, 4.5, 4.5, 4.85, 3.95, 4.66, 4.5, 4.78, 4.57, 3.5, 3.73, 4.69, 3.16, 3.1, 2.96,
    3.37, 6.01, 6.67, 5.82, 6.15, 7.06, 6.41, 6.88, 5.89, 7.09,
]

# Generate an array of days for monsoon months
days_monsoon = np.arange(1, len(uva_data_monsoon) + 1)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days_monsoon, uva_data_monsoon, label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Julian Days', fontsize=14)
ax1.set_ylabel('UV-A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days_monsoon, bhss_data_monsoon, label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Calculate correlation coefficient
correlation_coefficient = np.corrcoef(uva_data_monsoon, bhss_data_monsoon)[0, 1]
print("Correlation Coefficient:", correlation_coefficient)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=8, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('Monsoon UV-A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path = 'monsoon_uv_bhss_plot.png'
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path}")

# Display the plot
plt.show()
# Out:
# Correlation Coefficient: 0.8231666058356609
# Plot saved as: monsoon_uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data for post-monsoon months
uva_data_oct_dec = [
    # October
    7.954375, 9.206249, 9.7188, 9.126416, 9.3717, 10.9915, 10.660598, 10.891998, 10.109866, 9.268727,
    8.2147, 9.222447, 8.9089, 8.3304, 8.605766, 8.749234, 8.727251, 8.171891, 8.605766, 8.099, 8.248253,
    8.777002, 8.715681, 8.426431, 8.942453, 8.74692, 8.50395, 9.102119, 8.88576, 9.3717, 8.697169,
    # November
    8.118669, 8.648575, 8.721466, 8.627749, 8.693698, 8.711053, 8.61965, 9.062781, 9.1403, 8.777002,
    8.697169, 8.195031, 8.118669, 8.132553, 7.558681, 8.049249, 8.115198, 7.768098, 7.424469, 7.211581,
    7.732231, 7.616531, 8.5618, 7.153731, 9.074351, 7.70562, 8.002969, 6.925802, 8.626592, 7.940491,
    # December
    6.961669, 7.0577, 7.536698, 6.942, 5.59988, 7.33538, 7.33538, 6.96514, 7.01142, 7.35852, 7.157202,
    6.76845, 6.54862, 8.14528, 6.30565, 7.4048, 6.961669, 7.554053, 7.46265, 7.68248, 7.211581, 6.8263,
    7.0577, 6.908447, 6.7106, 7.33538, 6.61804, 6.942, 6.806631, 7.223151, 7.206953,
]

# BHSS data for post-monsoon months
bhss_data_oct_dec = [
    # October
    4.58, 5.97, 5.36, 3.68, 5.68, 7.64, 5.91, 6.78, 6.59, 6.17, 5.79, 6.79, 6.53, 6.71, 6.82, 6.76, 6.96, 5.85,
    7.75, 7.05, 5.99, 6.51, 7.33, 6.2, 6.57, 5.65, 7.14, 8.26, 8.2, 8.84, 7.51,
    # November
    6.775, 8.3, 8.7, 8.05, 8.225, 8.2875, 8.6, 9.0625, 8.8125, 8.9, 9.15, 9.0375, 9.0625, 8.9375, 8.1625, 8.825,
    8.875, 8.2875, 8.45, 7.7125, 8.1625, 8.2125, 8.0625, 7.5625, 6.8125, 7.3, 7.6125, 5.975, 8.4625, 7.65,
    # December
    6.62, 7.63, 7.9, 6.98, 6.93, 8.19, 8.47, 8.48, 8.67, 8.65, 7.81, 8.12, 7.61, 6.64, 7.31, 8.2, 7.68, 8.13,
    7.92, 8.31, 8.33, 7.388888889, 8.16, 7.93, 8.08, 8.4, 8.36, 8.36, 8.24, 8.31, 7.39,
]

# Generate an array of days for post-monsoon months
days_oct_dec = np.arange(1, len(uva_data_oct_dec) + 1)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days_oct_dec, uva_data_oct_dec, label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Julian Days', fontsize=14)
ax1.set_ylabel('UV-A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days_oct_dec, bhss_data_oct_dec, label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=8, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('Post-Monsoon UV-A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path_oct_dec = 'post_monsoon_uv_bhss_plot.png'
plt.savefig(output_file_path_oct_dec, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path_oct_dec}")

# Display the plot
plt.show()
# Out:
# Plot saved as: post_monsoon_uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# UV A data for post-monsoon months
uva_data_oct_dec = [
    # October
    7.954375, 9.206249, 9.7188, 9.126416, 9.3717, 10.9915, 10.660598, 10.891998, 10.109866, 9.268727,
    8.2147, 9.222447, 8.9089, 8.3304, 8.605766, 8.749234, 8.727251, 8.171891, 8.605766, 8.099, 8.248253,
    8.777002, 8.715681, 8.426431, 8.942453, 8.74692, 8.50395, 9.102119, 8.88576, 9.3717, 8.697169,
    # November
    8.118669, 8.648575, 8.721466, 8.627749, 8.693698, 8.711053, 8.61965, 9.062781, 9.1403, 8.777002,
    8.697169, 8.195031, 8.118669, 8.132553, 7.558681, 8.049249, 8.115198, 7.768098, 7.424469, 7.211581,
    7.732231, 7.616531, 8.5618, 7.153731, 9.074351, 7.70562, 8.002969, 6.925802, 8.626592, 7.940491,
    # December
    6.961669, 7.0577, 7.536698, 6.942, 5.59988, 7.33538, 7.33538, 6.96514, 7.01142, 7.35852, 7.157202,
    6.76845, 6.54862, 8.14528, 6.30565, 7.4048, 6.961669, 7.554053, 7.46265, 7.68248, 7.211581, 6.8263,
    7.0577, 6.908447, 6.7106, 7.33538, 6.61804, 6.942, 6.806631, 7.223151, 7.206953,
]

# BHSS data for post-monsoon months
bhss_data_oct_dec = [
    # October
    4.58, 5.97, 5.36, 3.68, 5.68, 7.64, 5.91, 6.78, 6.59, 6.17, 5.79, 6.79, 6.53, 6.71, 6.82, 6.76, 6.96, 5.85,
    7.75, 7.05, 5.99, 6.51, 7.33, 6.2, 6.57, 5.65, 7.14, 8.26, 8.2, 8.84, 7.51,
    # November
    6.775, 8.3, 8.7, 8.05, 8.225, 8.2875, 8.6, 9.0625, 8.8125, 8.9, 9.15, 9.0375, 9.0625, 8.9375, 8.1625, 8.825,
    8.875, 8.2875, 8.45, 7.7125, 8.1625, 8.2125, 8.0625, 7.5625, 6.8125, 7.3, 7.6125, 5.975, 8.4625, 7.65,
    # December
    6.62, 7.63, 7.9, 6.98, 6.93, 8.19, 8.47, 8.48, 8.67, 8.65, 7.81, 8.12, 7.61, 6.64, 7.31, 8.2, 7.68, 8.13,
    7.92, 8.31, 8.33, 7.388888889, 8.16, 7.93, 8.08, 8.4, 8.36, 8.36, 8.24, 8.31, 7.39,
]

# Generate an array of days for post-monsoon months
days_oct_dec = np.arange(1, len(uva_data_oct_dec) + 1)

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot UV A data on the primary y-axis
ax1.plot(days_oct_dec, uva_data_oct_dec, label='UV A', color='#FF5757', linewidth=2)
ax1.set_xlabel('Julian Days', fontsize=14)
ax1.set_ylabel('UV-A (W/m^2)', color='#FF5757', fontsize=14)

# Create a secondary y-axis for BHSS data
ax2 = ax1.twinx()
ax2.plot(days_oct_dec, bhss_data_oct_dec, label='BHSS', color='#5799FF', linewidth=2)
ax2.set_ylabel('BHSS (W/m^2)', color='#5799FF', fontsize=14)

# Calculate correlation coefficient
correlation_coefficient_oct_dec = np.corrcoef(uva_data_oct_dec, bhss_data_oct_dec)[0, 1]
print("Correlation Coefficient (October-December):", correlation_coefficient_oct_dec)

# Add grid lines for better readability
ax1.grid(True, linestyle='--', alpha=0.7)

# Customize legend with a border box and adjust fontsize
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', fontsize=8, borderpad=1, fancybox=True, edgecolor='black')

# Add title
plt.title('Post-Monsoon UV-A and BHSS Data Over Days', fontsize=12)

# Save the plot as a PNG image file
output_file_path_oct_dec = 'post_monsoon_uv_bhss_plot.png'
plt.savefig(output_file_path_oct_dec, bbox_inches='tight', dpi=300)

# Print the path to the saved image file
print(f"Plot saved as: {output_file_path_oct_dec}")

# Display the plot
plt.show()
# Out:
# Correlation Coefficient (October-December): -0.2736914693037169
# Plot saved as: post_monsoon_uv_bhss_plot.png

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

             10.03, 9.58, 10.08, 9.6, 8.95, 10.1, 8.32, 7.73, 6.04, 6.41, 6.01, 4.93, 6.42, 7.04, 4.99, 5.17,
             5.33, 5.77, 6.24, 5.7, 4.85, 5.35, 4.17, 3.91, 5.22, 5.83, 5.555555556, 5.988888889, 5.53, 3.12,
             3.91, 4.23, 4.73, 3.91, 3.71, 5.344444444, 4.72, 4.14, 2.89, 3.1, 3.78, 2.166666667, 2.544444444,
             2.99, 3, 2.466666667, 3.033333333, 2.477777778, 2.96, 3.33, 2.21, 2.44, 3.37, 2.05, 3.1, 1.25,
             1.72, 1.52, 1.555555556, 3.225, 3.03, 2.288888889, 1.37, 1.75, 1.81, 2.488888889, 2.466666667,
             2.92, 2.54, 3.18, 2.52, 2.25, 1.76, 2.72, 3.17, 2.58, 2.56, 3.02, 2.92, 3.37, 4.19, 4.49, 4.26,
             5.16, 5.01, 4.51, 4.93, 3.92, 4.32, 5.17, 6.24, 3.93, 3.35, 1.27, 2.1, 3.99, 3.97, 4.83, 3.98,
             3.39, 6.04, 5.39, 6.71, 4.5, 4.5, 4.85, 3.95, 4.66, 4.5, 4.78, 4.57, 3.5, 3.73, 4.69, 3.16, 3.1,
             2.96, 3.37, 6.01, 6.67, 5.82, 6.15, 7.06, 6.41, 6.88, 4.58, 5.97, 5.36, 3.68, 5.68, 7.64, 5.91,
             6.78, 6.59, 6.17, 5.79, 6.79, 6.53, 6.71, 6.82, 6.76, 6.96, 5.85, 7.75, 7.05, 5.99, 6.51, 7.33,
             6.2, 6.57, 5.65, 7.14, 8.26, 8.2, 8.84, 7.51, 6.775, 8.3, 8.7, 8.05, 8.225, 8.2875, 8.6, 9.0625,
             8.8125, 8.9, 9.15, 9.0375, 9.0625, 8.9375, 8.1625, 8.825, 8.875, 8.2875, 8.45, 7.7125, 8.1625,
             8.2125, 8.0625, 7.5625, 6.8125, 7.3, 7.6125, 5.975, 8.4625, 7.65, 6.62, 7.63, 7.9, 6.98, 6.93,
             8.19, 8.47, 8.48, 8.67, 8.65, 7.81, 8.12, 7.61, 6.64, 7.31, 8.2, 7.68, 8.13, 7.92, 8.31, 8.33,
             7.388888889, 8.16, 7.93, 8.08, 8.4, 8.36, 8.36, 8.24, 8.31, 7.39]

# Trim uva_data to match the length of bhss_data
uva_data = uva_data[:len(bhss_data)]

# Calculate regression line
slope, intercept, r_value, _, _ = linregress(bhss_data, uva_data)
regression_line = slope * np.array(bhss_data) + intercept

# Plot scatter graph
plt.figure(figsize=(8, 6))
plt.scatter(bhss_data, uva_data, color='blue', label='Data Points')

# Plot regression line
plt.plot(bhss_data, regression_line, color='red', label='Regression Line')

# Add correlation value as text
plt.text(0.40, 0.97, f'Correlation: {r_value:.2f}', transform=plt.gca().transAxes, fontsize=12,
         verticalalignment='top')

# Add labels and title
plt.xlabel('BHSS (W/m^2)', fontsize=14)
plt.ylabel('UV-A (W/m^2)', fontsize=14)
plt.title('Scatter Plot of UV-A vs. BHSS', fontsize=16)

# Add legend
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.savefig('output_plot.png')
plt.show()
